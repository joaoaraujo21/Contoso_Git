# %%
# Cria o texto do nosso arquivo CSV de teste (com um preço negativo e um sem cliente)
conteudo_csv = """product_id,customer_id,price
P10,C01,3500.00
P13,C02,-800.00
P11,,120.00"""

# O dbutils cria a pasta (se não existir) e salva o arquivo lá dentro
dbutils.fs.put("/Volumes/workspace/datamart/varejo/vendas_streaming/dados_iniciais.csv", conteudo_csv, True)

print("✅ Pasta e arquivo criados com sucesso! O DLT já tem o que ler.")
